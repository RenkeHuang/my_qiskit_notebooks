# %%
from qiskit import *

# %% [markdown]
# ## State vector

# %%
cir = QuantumCircuit(1,1)
cir.h(0)
simulator = Aer.get_backend('statevector_simulator')
result = execute(cir, backend=simulator).result()

# %%
statevec = result.get_statevector()
print(statevec)
cir.draw(output='mpl')
# Out:
# [0.70710678+0.j 0.70710678+0.j]

# %% [markdown]
# ## Bloch sphere (show state vector)

# %%
from qiskit.tools.visualization import plot_bloch_multivector

# %%
plot_bloch_multivector(statevec)

# %%
cir.measure(0,0)
result = execute(cir, backend=Aer.get_backend('qasm_simulator'),shots=1024).result()
counts = result.get_counts()

# %%
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)

# %% [markdown]
# ## Unitary Matrix Representation of Gates/Circuits

# %%
cir2 = QuantumCircuit(1,1)
cir2.x(0)
simulator2 = Aer.get_backend('unitary_simulator')
result = execute(cir2, backend=simulator2).result()
unitary = result.get_unitary()
print(unitary)
# cir.draw(output='mpl')
# Out:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]
